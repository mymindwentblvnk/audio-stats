# %%
import pandas as pd
import csv
import glob
from datetime import datetime

CSV_GLOB_PATTERN = '../plays/*.csv'

POSSIBLE_TIMESTAMP_COLUMN_NAMES = ['uts', 'timestamp']
POSSIBLE_ARTIST_COLUMN_NAMES = ['artist']
POSSIBLE_TITLE_COLUMN_NAMES = ['title', 'track']
POSSIBLE_ALBUM_COLUMN_NAMES = ['album']

PLAYED_AT = 'played_at_utc'
ARTIST_NAME = 'artist_name'
TRACK_TITLE = 'track_title'
ALBUM_TITLE = 'album_title'
DF_HEADER = [PLAYED_AT, ARTIST_NAME, TRACK_TITLE, ALBUM_TITLE]


def get_column_name(df, possible_column_names):
    for n in possible_column_names:
        if n in df:
            return n

        
def timestamp_to_datetime(timestamp):
    return datetime.fromtimestamp(int(timestamp))


def load_data_frame():
    result = pd.DataFrame(columns=DF_HEADER)
    
    for file_path in glob.glob(CSV_GLOB_PATTERN):
        rows = None
        with open(file_path, 'r') as csv_in:
            rows = list(csv.DictReader(csv_in))
        df = pd.DataFrame(rows)

        timestamp_column_name = get_column_name(df, POSSIBLE_TIMESTAMP_COLUMN_NAMES)
        artist_column_name = get_column_name(df, POSSIBLE_ARTIST_COLUMN_NAMES)
        title_column_name = get_column_name(df, POSSIBLE_TITLE_COLUMN_NAMES)
        album_column_name = get_column_name(df, POSSIBLE_ALBUM_COLUMN_NAMES)
        
        df.rename(columns={timestamp_column_name: PLAYED_AT,
                           artist_column_name: ARTIST_NAME,
                           title_column_name: TRACK_TITLE,
                           album_column_name: ALBUM_TITLE}, inplace=True)
        
        result = result.append(df[DF_HEADER])    
    result[PLAYED_AT] = result[PLAYED_AT].apply(timestamp_to_datetime)
    return result

# %%
df = load_data_frame()

# %%
df.groupby([TRACK_TITLE, ARTIST_NAME])[TRACK_TITLE]\
    .count()\
    .reset_index(name='count').sort_values(['count'], ascending=False)\
    .head(100)
# Out:
#                                              track_title        artist_name  \
# 20071                                 The Damage Is Done          Foreigner
# 14782                                      Of a Lifetime            Journey
# 14025                                              Naïve          The Kooks
# 22369                               Weil du mich liebst?              J-Luv
# 24008                                   will you miss me         Heatmakerz
# 11506                                           La La La              LMFAO
# 15744                               Please Please Please    Shout Out Louds
# 21954                                 Walk These Streets              Rakim
# 23705                                         computiful                Cro
# 11958  Letzeee Gooo (L.A.A.S.A.V.A.S.) (Feat. Laas Un...         Kool Savas
# 18451                               Something In the Air    Sarah Brightman
# 10800                                            Join Me                Him
# 16404                                            Receipt         Lil' Wayne
# 20674                                      Things You Do            50 Cent
# 10904                                         Just Dance          Lady Gaga
# 23854                                     more more more            Capsule
# 9817                               I've Tried Everything         Eurythmics
# 9073                                     How will I know             RePete
# 15345                         Paper Chaser (Feat. Jay K)           Big Sean
# 9084                                            Hum Drum  Theophilus London
# 8606       Hero (Exclusive) (Album "KOLLEGAH" ab 29.08.)           Kollegah
# 15183                                              Outro           Kollegah
# 15716                     Play with Bootsy ft. Kelli Ali     Bootsy Collins
# 11978                                      Liberian Girl    Michael Jackson
# 7610         Gifted ft. KanYe West, Santogold & Lykke Li           N.A.S.A.
# 19092                                      Street Lights         Kanye West
# 22831                                           Who I Am      The Diplomats
# 8764                                             History              Jay-Z
# 12523                              Love LockDown (Remix)              LMFAO
# 12201                        Little Bit (feat. Lykke Li)              Drake
# ...                                                  ...                ...
# 2339   Beweg Dein Arsch (feat. Kitty Kat, Tony D, Sco...               Sido
# 23276                                               Yeah       Bumm Tschack
# 5224                                           Don't Cry      Guns N' Roses
# 7255                                    Gangsterarroganz           Kollegah
# 17756     Ship (Instrumental) - myspace.com/repetesworld             RePete
# 5891            Empire State of Mind (feat. Alicia Keys)              Jay-Z
# 12001                                    Lieblingsmensch              Remoe
# 19108                            Streets of Philadelphia  Bruce Springsteen
# 23307                                                Yes              LMFAO
# 22238                           We Didn't Start the Fire         Billy Joel
# 13779                  My Cool (Prod. Addeboy vs. Cliff)        Adam Tensta
# 13665  Mr. Carter (Featuring Jay-Z) (Produced By Just...         Lil' Wayne
# 15219                                               Over              Drake
# 10973  Kanye West - Paranoid Feat. LMFAO (Party Rock ...              LMFAO
# 23984                          unendlichkeit - Main Edit                Cro
# 23874                                          numero 10              Booba
# 7000                      Friends no more (Instrumental)         The Cohens
# 13778                                            My Cool        Adam Tensta
# 7833                                                Gone             Donnis
# 3172                                          Butterflys         Kool Savas
# 7874                                        Good Ol Love          Masta Ace
# 3043                       Bromance (Avicii's Arena Mix)           Tim Berg
# 8895                            Hometown (feat. Ace Mac)            chi-ill
# 3118                           Bulletproof (Foamo Remix)            La Roux
# 12572                                        Love You So       St. Lunatics
# 23975                                                tru                Cro
# 13312                                      Mirror's Edge                 XV
# 15635                                        Pillow Talk           Kid Cudi
# 5385                                Doubletime Freestyle           Kollegah
# 5288                                 Don't Stop Believin            Journey
#
#        count
# 20071    384
# 14782    165
# 14025    140
# 22369    140
# 24008    139
# 11506    132
# 15744    130
# 21954    130
# 23705    127
# 11958    124
# 18451    119
# 10800    118
# 16404    117
# 20674    115
# 10904    109
# 23854    109
# 9817     107
# 9073     107
# 15345    104
# 9084     103
# 8606     103
# 15183    101
# 15716    100
# 11978    100
# 7610     100
# 19092     99
# 22831     99
# 8764      95
# 12523     95
# 12201     95
# ...      ...
# 2339      74
# 23276     74
# 5224      73
# 7255      73
# 17756     72
# 5891      72
# 12001     72
# 19108     72
# 23307     72
# 22238     71
# 13779     71
# 13665     71
# 15219     70
# 10973     69
# 23984     69
# 23874     69
# 7000      68
# 13778     68
# 7833      68
# 3172      67
# 7874      67
# 3043      66
# 8895      66
# 3118      66
# 12572     66
# 23975     66
# 13312     66
# 15635     65
# 5385      65
# 5288      65
#
# [100 rows x 3 columns]

# %%
df.groupby([ALBUM_TITLE, ARTIST_NAME])[ALBUM_TITLE]\
    .count()\
    .reset_index(name='count').sort_values(['count'], ascending=False)\
    .head(100)
# Out:
#                                       album_title     artist_name  count
# 11705                       tru. (Deluxe Edition)             Cro   1153
# 6720                     Minecraft - Volume Alpha            C418   1017
# 349                                                      Kollegah    580
# 7537                             Palmen & Freunde          Dexter    574
# 589                                                   Tax Awesome    548
# 492                                                        RePete    535
# 6564              Man on the Moon: The End of Day        Kid Cudi    509
# 9590                               Thank Me Later           Drake    459
# 359                                                         LMFAO    431
# 5883                                     Kollegah        Kollegah    421
# 848                                          1997          Alicks    419
# 1005                            808s & Heartbreak      Kanye West    415
# 1370                                    Alphagene        Kollegah    398
# 5960                          Kush & Orange Juice     Wiz Khalifa    376
# 8264                                         Rise   Guerilla Maab    375
# 8391                   Russisch Roulette (Deluxe)      Haftbefehl    357
# 575                                                        Syntax    346
# 8882                                  So Far Gone           Drake    343
# 6852                                     Movement          Monroe    340
# 7447                         Oracular Spectacular            MGMT    340
# 801                  10551 moabit island season 1          morten    337
# 5796                                 Killerspiele          Morbid    320
# 9730                              The Blueprint 3           Jay-Z    317
# 10497                         To Pimp a Butterfly  Kendrick Lamar    306
# 3143                       Dat Kid From Cleveland        Kid Cudi    300
# 11503                                Zuhältertape        Kollegah    299
# 1636                                 BB.U.M.SS.N.            SSIO    284
# 10025                      The Malady Of Elegance        Goldmund    280
# 8950                                    Sometimes        Goldmund    279
# 5511                               Intergalactica          LGoony    273
# ...                                           ...             ...    ...
# 6107                             Legal Drug Money       Lost Boyz    189
# 4155                                 Forever King         50 Cent    187
# 7411                                 One and Only            Sero    187
# 7251                Nothing Was The Same (Deluxe)           Drake    181
# 11604                              global players      Holy Modee    181
# 826                                            17    XXXTENTACION    180
# 6076                            Late Registration      Kanye West    180
# 499                                                     Rick Ross    178
# 11607             good kid, m.A.A.d city (Deluxe)  Kendrick Lamar    176
# 5936                                    Kontraste           J-Luv    176
# 11009                                 Walthamstow         East 17    176
# 4838                                   Heartbeats            Grum    175
# 4885                               Hempstead High              A+    174
# 10747                                UKNOWBIGSEAN        Big Sean    173
# 6948                       My Krazy Life (Deluxe)              YG    173
# 8524                                     Scorpion           Drake    171
# 4461                Glamrockrapper 2 - The Add On        Rockstah    169
# 5668                                      Journey         Journey    169
# 4780                                   Hard Candy         Madonna    165
# 2901                                    Crossroad        Bon Jovi    163
# 4247                                 From Me To U   Juelz Santana    162
# 11606                      good kid, m.A.A.d city  Kendrick Lamar    161
# 108                                                        Cassie    161
# 3323   Diary of an ATL Brave presented by 10.Deep          Donnis    160
# 5829                           Kiss Land (Deluxe)      The Weeknd    160
# 352                                                    Kool Savas    159
# 6488                            MORE! MORE! MORE!         Capsule    158
# 6335                                        Loose   Nelly Furtado    158
# 717                                     #hangster     Psaiko.Dino    158
# 7822                      Presents Shock Value II       Timbaland    156
#
# [100 rows x 3 columns]

# %%
df.groupby([ARTIST_NAME])[ARTIST_NAME]\
    .count()\
    .reset_index(name='count').sort_values(['count'], ascending=False)\
    .head(100)
# Out:
#                 artist_name  count
# 2867               Kollegah   2501
# 1509                  Drake   1984
# 2713             Kanye West   1789
# 1075                    Cro   1483
# 2800               Kid Cudi   1396
# 779                    C418   1148
# 5601            Wiz Khalifa   1102
# 4285              Rick Ross   1042
# 2776         Kendrick Lamar    996
# 47                  50 Cent    904
# 3076             Lil' Wayne    862
# 5708                   Z-Ro    743
# 2457                  Jay-Z    736
# 2937                  LMFAO    721
# 5223             The Weeknd    719
# 1379                 Dexter    710
# 3095         Little Brother    706
# 4387          Royce da 5'9"    700
# 4983            Tax Awesome    678
# 539                Big Sean    677
# 4940                   T.I.    668
# 3471        Michael Jackson    597
# 4229                 RePete    577
# 4869                Stromae    569
# 2040               Goldmund    559
# 2154             Heatmakerz    552
# 2878             Kool Savas    550
# 1836              Foreigner    542
# 755                 Bushido    537
# 934             Chris Brown    533
# ...                     ...    ...
# 809           Calvin Harris    291
# 1146              DJ Khaled    282
# 119             Adam Tensta    282
# 5527                   Wale    281
# 5098          The Diplomats    277
# 1866         Franky Kubrick    270
# 1557        Dynamite Deluxe    267
# 2829           King Garbage    264
# 2386               Jadakiss    261
# 5139           The Internet    261
# 62               9th Wonder    259
# 811                 Cam'ron    257
# 1612              Eko Fresh    252
# 2869  Kollegah & Farid Bang    249
# 2605                Journey    249
# 1903        Frédéric Chopin    247
# 5238      Theophilus London    246
# 733              Bruno Mars    240
# 1296           David Guetta    238
# 749                  Burial    237
# 4330               Rockstah    236
# 4397             Rudimental    234
# 3257                Madonna    234
# 4933      Sébastien Tellier    233
# 526                 Big Boi    230
# 2342                  J-Luv    229
# 73                       A+    227
# 2657      Justin Timberlake    221
# 1651                 Eminem    219
# 978            Clams Casino    219
#
# [100 rows x 2 columns]
